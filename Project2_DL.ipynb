# %% [markdown]
# <a href="https://colab.research.google.com/github/Gopi138942/swin_transformer/blob/main/Project2_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-58dd83e7-b6ef-4d86-9cba-59c8eaed8081" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-58dd83e7-b6ef-4d86-9cba-59c8eaed8081">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import randomaug

# %%
import Utils

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install swin-transformer-pytorch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 63.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 53.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
sys.path.append('/content/drive/MyDrive')
from mod import Utils

# %%
import sys
sys.path.append('/content/drive/MyDrive/mod')
from  swin_transformer_pytorch import swin_transformer

# %%
sys.path.append('/content/drive/MyDrive/mod')
from  swin_transformer_pytorch import __init__

# %%
sys.path.append('/content/drive/MyDrive')
from mod import randomaug

# %%
sys.path.append('/content/drive/MyDrive')
from mod import __init__

# %%
# !python3 /content/drive/MyDrive/mod/swin_main.py
# Out:
# Streaming output truncated to the last 5000 lines.
# 494 782 Loss: 0.838 | TrainAcc: 68.166% (21595/31680)
# 495 782 Loss: 0.837 | TrainAcc: 68.174% (21641/31744)
# 496 782 Loss: 0.837 | TrainAcc: 68.172% (21684/31808)
# 497 782 Loss: 0.837 | TrainAcc: 68.160% (21724/31872)
# 498 782 Loss: 0.837 | TrainAcc: 68.171% (21771/31936)
# 499 782 Loss: 0.837 | TrainAcc: 68.175% (21816/32000)
# 500 782 Loss: 0.837 | TrainAcc: 68.173% (21859/32064)
# 501 782 Loss: 0.837 | TrainAcc: 68.180% (21905/32128)
# 502 782 Loss: 0.837 | TrainAcc: 68.197% (21954/32192)
# 503 782 Loss: 0.836 | TrainAcc: 68.198% (21998/32256)
# 504 782 Loss: 0.836 | TrainAcc: 68.196% (22041/32320)
# 505 782 Loss: 0.836 | TrainAcc: 68.194% (22084/32384)
# 506 782 Loss: 0.837 | TrainAcc: 68.171% (22120/32448)
# 507 782 Loss: 0.837 | TrainAcc: 68.166% (22162/32512)
# 508 782 Loss: 0.837 | TrainAcc: 68.170% (22207/32576)
# 509 782 Loss: 0.837 | TrainAcc: 68.162% (22248/32640)
# ...
